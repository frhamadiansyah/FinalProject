# %% [markdown]
# ## 1. Import Library and Dataset

# %%
import nltk # Imports the library
# nltk.download_shell() #Download the necessary datasets
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import string
import re
# %matplotlib inline

# %%
# df = pd.read_csv('Dataset/Indonesian Sentiment Twitter Dataset Labeled.csv', sep = '\t')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10806 entries, 0 to 10805
# Data columns (total 5 columns):
# Unnamed: 0    10806 non-null int64
# sentimen      10806 non-null int64
# Tweet         10806 non-null object
# hashtag       0 non-null float64
# no_link       10695 non-null object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 422.2+ KB

# %%
df.head()
# Out:
#    sentimen                                              Tweet
# 0        -1  lagu bosan apa yang aku save ni huhuhuhuhuhuhu...
# 1        -1  kita lanjutkan saja diam ini hingga kau dan ak...
# 2         1  doa rezeki tak putus inna haa zaa larizquna ma...
# 3         1  makasih loh ntar kita bagi hasil aku 99 9 sisa...
# 4        -1  aku tak faham betul jenis orang malaysia yang ...

# %%
df.sentimen.value_counts()
# Out:
#  0    5327
# -1    2887
#  1    2592
# Name: sentimen, dtype: int64

# %% [markdown]
# ### 1a. Add Extra Feature to Simplify Analysis

# %%
## add hashtag columns
def check_hashtag(x):
    if len(re.findall(r'#\w+', x)) == 0:
        return None
    else :
        return ' '.join(re.findall(r'#\w+', x))

df['hashtag'] = df['Tweet'].apply(check_hashtag)

# %%
def clean_link(text):
    #lowercase all
    text = text.lower()
    #hapus RT
    text=re.sub('^rt @[^\s]+','',text)
    #text = re.sub(',','',text)
    text=re.sub(r'http\S+','',text)
    #hapus \n
    text=re.sub('\n',' ',text)

    return text

df['no_link'] = df['Tweet'].apply(clean_link)

# %%
def unicode_text(x):
    x = re.findall(r'\\u[0-9a-fA-F]{4}|\\U[0-9a-fA-F]{8}',x)
    if len(x) == 0:
        return False
    else:
        return True
df['unicode'] = df['no_link'].apply(unicode_text)

# %%
# f = 'ibu, terima kasih atas doa dan kumpulan pelajaran yang telah membangun pemikiran, karakter dan semangat untuk berju\\u2026'.split()
# mylist = [line for line in f]
# unicode_literal = re.compile(r'\\u[0-9a-fA-F]{4}|\\U[0-9a-fA-F]{8}')
# kalimat = []
# for i in mylist:
#     kalimat.append(unicode_literal.sub(r'', i))
# ' '.join(kalimat)
df.shape
# Out:
# (10806, 4)

# %%
df[df['Tweet'] != df['no_link']]
# Out:
#        sentimen                                              Tweet hashtag  \
# 284           0  nctea selama ini aku cuma tau fotonya jisung a...    None
# 933           0  nctea selama ini aku cuma tau fotonya jisung a...    None
# 1097          1  aku suka orang cakap macam ni even tak rasa be...    None
# 1272          0  berkenan betul aku dgn concept design ikea ni ...    None
# 1277         -1  iPhone tak mahal aku rasa Ikut market price an...    None
# 1359         -1  admin tau kalo hoseok bisa nyetir tapi kenapa ...    None
# 1658          1  chemotherapy gdp cycle 2 day 1 orang lain sibu...    None
# 2208          1  aku suka orang cakap macam ni even tak rasa be...    None
# 2412          1  aku suka orang cakap macam ni even tak rasa be...    None
# 2721          1  berkenan betul aku dgn concept design ikea ni ...    None
# 3171          0  nctea selama ini aku cuma tau fotonya jisung a...    None
# 10797  jadi kita harus mkn dulu di kfc sebesar 60 rib...
# 10798  tante kapan nikah akun rp panggil calon istri ...
# 10799  pelik tengok orang zaman sekarang ni dulu kema...
# 10800  menikah itu belum tentu harus sudah pernah pac...
# 10801  jangan membandingkan kehidupanmu dengan kehidu...
# 10802                      sini uname lu ntar gua follow
# 10803  apapun yg telah kamu lakukan apapun kesalahanm...
# 10805  semoga allah permudahkan urusan aku amp orang ...
#
# [372 rows x 4 columns]

# %% [markdown]
# ## 2. Clean up typo

# %%
kamusalay_2 = pd.read_csv('Dataset/colloquial-indonesian-lexicon.csv')

kamusalay_2['Alay'] =kamusalay_2['slang']

kamusalay_2['KBBI'] =kamusalay_2['formal']
kamusalay_2.drop('slang formal In-dictionary context category1 category2 category3'.split(), axis = 1, inplace = True)
kamusalay_2.shape
# Out:
# (15006, 2)

# %%
kamusalay = pd.read_csv('Dataset/kamusalay.csv', header = None)
kamusalay.columns = ['Alay', 'KBBI']
kamusalay.shape
# Out:
# (238, 2)

# %%
kamus_alay = pd.merge(kamusalay, kamusalay_2, how = 'outer')
kamus_alay.drop_duplicates(subset = 'Alay', inplace = True)
kamus_alay.reset_index(inplace = True, drop = True)
# kamus_alay.shape

kamus = {}
# kamus_alay[kamus_alay['Alay'] == 'gw']
for index, row in kamus_alay.iterrows():
    kamus[row['Alay']] = row['KBBI']

# %%
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

def hapus_katadouble(s): 
    #look for 2 or more repetitions of character and replace with the character itself
    pattern = re.compile(r"(.)\1{1,}", re.DOTALL)
    return pattern.sub(r"\1\1", s)


def text_process(text):
    """
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Remove all stopwords
    3. Returns a list of the cleaned text
    4. Remove all string not in number
    """
    #lowercase all
    text = text.lower()
    #hapus RT
    text=re.sub('^rt @[^\s]+','',text)
#     text = re.sub(',','',text)
    text=re.sub(r'http\S+','',text)
	#hapus @username
    text=re.sub('@[^\s]+','',text)
	#hapus #tagger 
#     text = re.sub(r'#([^\s]+)', r'\1', text)
    text = re.sub(r'#([^\s]+)', '', text)
    #hapus tanda baca dan angka
    hapus = string.punctuation + '0123456789'
    text = [char for char in text if char not in hapus]
    text = ''.join(text)
    # substitute slang word
    text = text.split()
    global kamus
    for i in range(len(text)):
        if text[i] in kamus.keys():
            text[i] = kamus[text[i]]
    
    text = ' '.join(text)
    
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    
    kalimat = ' '.join([hapus_katadouble(word) for word in text.split() if word.lower() not in stopwords.words('indonesian')])
    
    return stemmer.stem(kalimat)


text_process('apaan')
# Out:
# ''

# %%
df['no_link'] = df['no_link'].apply(text_process)

# %%
df.head()
# Out:
#    sentimen                                              Tweet hashtag  \
# 0        -1  lagu bosan apa yang aku save ni huhuhuhuhuhuhu...    None
# 1        -1  kita lanjutkan saja diam ini hingga kau dan ak...    None
# 2         1  doa rezeki tak putus inna haa zaa larizquna ma...    None
# 3         1  makasih loh ntar kita bagi hasil aku 99 9 sisa...    None
# 4        -1  aku tak faham betul jenis orang malaysia yang ...    None
#
#                                              no_link
# 0              lagu bosan save huhuhuhuhuhuhuhuhuhuu
# 1                   lanjut diam erti sama libat hati
# 2  doa rezeki putus inna haa zaa larizquna maa la...
# 3                  terima kasih loh entar hasil sisa
# 4  faham jenis orang malaysia ret anak sangkut ho...

# %%
df.to_csv('sentiment_analysis_ID_clean.csv')

# %%
df = pd.read_csv('sentiment_analysis_ID_clean.csv')
df.head()
# Out:
#    Unnamed: 0  sentimen                                              Tweet  \
# 0           0        -1  lagu bosan apa yang aku save ni huhuhuhuhuhuhu...
# 1           1        -1  kita lanjutkan saja diam ini hingga kau dan ak...
# 2           2         1  doa rezeki tak putus inna haa zaa larizquna ma...
# 3           3         1  makasih loh ntar kita bagi hasil aku 99 9 sisa...
# 4           4        -1  aku tak faham betul jenis orang malaysia yang ...
#
#    hashtag                                            no_link
# 0      NaN              lagu bosan save huhuhuhuhuhuhuhuhuhuu
# 1      NaN                   lanjut diam erti sama libat hati
# 2      NaN  doa rezeki putus inna haa zaa larizquna maa la...
# 3      NaN                  terima kasih loh entar hasil sisa
# 4      NaN  faham jenis orang malaysia ret anak sangkut ho...

# %%
df['type'] = df['no_link'].apply(lambda x : str(type(x)))

# %%
df['type'].value_counts()
# Out:
# <class 'str'>      10695
# <class 'float'>      111
# Name: type, dtype: int64

# %%
df['type'].values
# Out:
# array(["<class 'str'>", "<class 'str'>", "<class 'str'>", ...,
#        "<class 'str'>", "<class 'str'>", "<class 'str'>"], dtype=object)

# %%
df[df['type'] == "<class 'float'>"]
# Out:
#        Unnamed: 0  sentimen  \
# 30             30         0
# 74             74         0
# 87             87         1
# 96             96         0
# 122           122         0
# 180           180        -1
# 191           191         0
# 294           294         0
# 410           410         1
# 496           496         1
# 763           763         0
# 780           780         1
# 878           878         1
# 974           974         0
# 1103         1103         0
# 1173         1173         0
# 1282         1282         0
# 1305         1305         1
# 1462         1462        -1
# 1530         1530        -1
# 1548         1548        -1
# 1586         1586         0
# 1730         1730         1
# 1748         1748         0
# 1886         1886         1
# 1936         1936        -1
# 2135         2135         1
# 2167         2167         0
# 2181         2181         0
# 2260         2260         0
# ...           ...       ...
# 7308         7308         0
# 7319         7319        -1
# 7326         7326         0
# 7496         7496         0
# 7925         7925         0
# 8025         8025         0
# 8040         8040         0
# 8216         8216         0
# 8470         8470         0
# 8663         8663         0
# 8847         8847         0
# 8997         8997         0
# 9044         9044         0
# 9053         9053         0
# 9091         9091         0
# 9130         9130         0
# 9173         9173        -1
# 9195         9195         0
# 9739         9739        -1
# 9797         9797        -1
# 9868         9868         0
# 9969         9969         1
# 10106       10106         0
# 10115       10115         0
# 10217       10217        -1
# 10363       10363         0
# 10487       10487         0
# 10651       10651         0
# 10718       10718         0
# 10740       10740        -1
#
#                                                    Tweet  hashtag no_link  \
# 30                                    aku tambah lagi ia      NaN     NaN
# 74                      ini tiga aku satu aja gapunya '       NaN     NaN
# 87                                   jadilah seperti aku      NaN     NaN
# 96                                        kamu juga kan       NaN     NaN
# 122                             karena aku kepo 11 13 20      NaN     NaN
# 180                                    kok gitu sama aku      NaN     NaN
# 191                                      sama aku kapan       NaN     NaN
# 294       kamu akan tanya karena aku pun juga mau tanya       NaN     NaN
# 410                                             aku mau       NaN     NaN
# 496                                           aku mauuuu      NaN     NaN
# 763                                           kamu juga       NaN     NaN
# 780                                       aku yang baik       NaN     NaN
# 878                                             ada aku       NaN     NaN
# 974              aku teringat bapak aku prnh ckp mcm tu       NaN     NaN
# 1103                             kapan aku dapet ginian       NaN     NaN
# 1173                                       aku disini' '      NaN     NaN
# 1282                                           kamu ugha      NaN     NaN
# 1305                                      benar kan aku       NaN     NaN
# 1462                              kamu kok gitu sama aq       NaN     NaN
# 1530   aku yang kurang atau kamu yang tidak pernah cu...      NaN     NaN
# 1548                                             ga ada       NaN     NaN
# 1586                                              sesama      NaN     NaN
# 1730                           sama aku juga sering gitu      NaN     NaN
# 1748                                                 aku      NaN     NaN
# 1886                                         aku aja aku      NaN     NaN
# 1936                   aku aja gatau aku ini siapa skrg       NaN     NaN
# 2135                                         aku maw kok      NaN     NaN
# 2167                       ni yg aku mkn selama 23 hari       NaN     NaN
# 2181                                         ma aku ajah      NaN     NaN
# 2260                                        aku di sini       NaN     NaN
# ...                                                  ...      ...     ...
# 7308                                           apa kamu       NaN     NaN
# 7319                                            ada apa       NaN     NaN
# 7326                                             dan 60       NaN     NaN
# 7496                                                5 3       NaN     NaN
# 7925         padahal kita bisa mendapatkan lebih banyak       NaN     NaN
# 8025                                           bila lagi      NaN     NaN
# 8040                             apakah kamu adalah aku       NaN     NaN
# 8216                          jadi kita kita mau gimana       NaN     NaN
# 8470                                      minta apa kamu      NaN     NaN
# 8663                               mereka selalu begitu       NaN     NaN
# 8847                            jadi apa kamu udah siap       NaN     NaN
# 8997              entah lah knp mereka bisa seperti ini       NaN     NaN
# 9044                                         siapa kamu       NaN     NaN
# 9053                                           aku kamu       NaN     NaN
# 9091                                              kamu d      NaN     NaN
# 9130                           sama2 kita sama sekarang       NaN     NaN
# 9173                                  tidak kamu gimana       NaN     NaN
# 9195                                   kamu kenapa kamu       NaN     NaN
# 9739                                 kamu aja yang gatau      NaN     NaN
# 9797                                  jadi kita itu apa       NaN     NaN
# 9868                                      kamu kapan ja       NaN     NaN
# 9969                                              selalu      NaN     NaN
# 10106                               apa kamu adalah aku       NaN     NaN
# 10115                                               kita      NaN     NaN
# 10217                                            ga           NaN     NaN
# 10363                                           kamu aja      NaN     NaN
# 10487                                Tapi kan kita sama       NaN     NaN
# 10651                                               KAMU      NaN     NaN
# 10718                                      macam kita do      NaN     NaN
# 10740                                      bukan ma kamu      NaN     NaN
#
#                   type
# 30     <class 'float'>
# 74     <class 'float'>
# 87     <class 'float'>
# 96     <class 'float'>
# 122    <class 'float'>
# 180    <class 'float'>
# 191    <class 'float'>
# 294    <class 'float'>
# 410    <class 'float'>
# 496    <class 'float'>
# 763    <class 'float'>
# 780    <class 'float'>
# 878    <class 'float'>
# 974    <class 'float'>
# 1103   <class 'float'>
# 1173   <class 'float'>
# 1282   <class 'float'>
# 1305   <class 'float'>
# 1462   <class 'float'>
# 1530   <class 'float'>
# 1548   <class 'float'>
# 1586   <class 'float'>
# 1730   <class 'float'>
# 1748   <class 'float'>
# 1886   <class 'float'>
# 1936   <class 'float'>
# 2135   <class 'float'>
# 2167   <class 'float'>
# 2181   <class 'float'>
# 2260   <class 'float'>
# ...                ...
# 7308   <class 'float'>
# 7319   <class 'float'>
# 7326   <class 'float'>
# 7496   <class 'float'>
# 7925   <class 'float'>
# 8025   <class 'float'>
# 8040   <class 'float'>
# 8216   <class 'float'>
# 8470   <class 'float'>
# 8663   <class 'float'>
# 8847   <class 'float'>
# 8997   <class 'float'>
# 9044   <class 'float'>
# 9053   <class 'float'>
# 9091   <class 'float'>
# 9130   <class 'float'>
# 9173   <class 'float'>
# 9195   <class 'float'>
# 9739   <class 'float'>
# 9797   <class 'float'>
# 9868   <class 'float'>
# 9969   <class 'float'>
# 10106  <class 'float'>
# 10115  <class 'float'>
# 10217  <class 'float'>
# 10363  <class 'float'>
# 10487  <class 'float'>
# 10651  <class 'float'>
# 10718  <class 'float'>
# 10740  <class 'float'>
#
# [111 rows x 6 columns]

# %%
df.drop('hashtag', axis = 1, inplace = True)
df.dropna(inplace = True)

# %% [markdown]
# ## 3. Data Visualization

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# wordcloud string
plt.figure(figsize = (12,8))
text = " ".join(review for review in df['Tweet'].dropna())
# text = ' '.join(word for word in df['text'] if word.contains('#'))

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# wordcloud hashtag
plt.figure(figsize = (12,8))
text = " ".join(review for review in df['hashtag'].dropna())
# text = ' '.join(word for word in df['text'] if word.contains('#'))

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
kotak = []
for review in df['no_link']:
    for a in review.split():
        kotak.append(a)

tally = {}
for i in kotak:
    if i in tally.keys():
        tally[i] += 1
    else : 
        tally[i] = 1

# %%
pd.Series(tally).sort_values(ascending = False)
# Out:
# ahok                                                                        449
# #debat2pilkadadki                                                           435
# yang                                                                        315
# dan                                                                         271
# yg                                                                          262
# di                                                                          246
# agus                                                                        225
# dia                                                                         211
# dki                                                                         192
# anies                                                                       172
# ini                                                                         160
# tidak                                                                       141
# pilih                                                                       134
# pilkada                                                                     134
# soal                                                                        121
# ke                                                                          117
# jakarta                                                                     108
# paslon                                                                      101
# bisa                                                                         98
# pikir                                                                        97
# saya                                                                         84
# tahun                                                                        80
# dalam                                                                        72
# kalau                                                                        71
# data                                                                         71
# mas                                                                          71
# ada                                                                          68
# 3                                                                            68
# mui                                                                          68
# itu                                                                          67
#                                                                            ...
# pilkades,                                                                     1
# pil                                                                           1
# kb,                                                                           1
# konser                                                                        1
# dahhh..                                                                       1
# band....,                                                                     1
# hadeh....                                                                     1
# alay.....,\u2026                                                              1
# singkaw...                                                                    1
# lunch                                                                         1
# sosok                                                                         1
# propaganda,                                                                   1
# kereeenn                                                                      1
# anehh                                                                         1
# 20%                                                                           1
# bin                                                                           1
# ajaib                                                                         1
# memaparkan                                                                    1
# transjakarta                                                                  1
# 6%                                                                            1
# aslinya                                                                       1
# (data                                                                         1
# menjawabnya.                                                                  1
# malaysiakini                                                                  1
# jelas)                                                                        1
# benernya                                                                      1
# \ud83d\ude4f\ud83c\udffd\ud83d\ude4f\ud83c\udffd\ud83d\ude4f\ud83c\udffd      1
# bgt                                                                           1
# pandai                                                                        1
# persidan\u2026                                                                1
# Length: 4242, dtype: int64

# %%
pd.set_option('display.max_columns', None)

# %%
df[df['no_link'].apply(lambda x : len(re.findall('u2026', x))) > 0]
# Out:
#                                                   Tweet  Label_Sentiment  \
# 1     rt @pandji: nah gue pikir sentimen petahana ok...                1
# 9     rt @aniesbaswedan: ibu, terima kasih atas doa ...                1
# 10    rt @gunromli: sylviana kesyikan ngomong sendir...                0
# 11    rt @gunromli: sylviana kesyikan ngomong sendir...                0
# 12    rt @gunromli: sylviana kesyikan ngomong sendir...                0
# 13    rt @gunromli: sylviana kesyikan ngomong sendir...                0
# 21    rt @gunromli: sylviana kesyikan ngomong sendir...                0
# 24    rt @teddygusnaidi: ini yg gue bilang, yg hebat...                0
# 27    rt @novnuraidah: sy ga percaya mpok @sylviana_...                1
# 28    rt @gunromli: sylviana kesyikan ngomong sendir...                1
# 32    rt @teddygusnaidi: 27. kalau gunakan fantasi a...                0
# 33    rt @teddygusnaidi: 28. kalau gunakan fantasi a...                0
# 34    rt @teddygusnaidi: para pemuja-pemuji @agusyud...                0
# 36    rt @aef8386: kata @aniesbaswedan ipm di ibu ko...                0
# 39    rt @teddygusnaidi: lah.. lu monolog sejam yg d...                0
# 41    rt @margareth_fh: dari dulu sampe sekarang ema...                1
# 42    rt @diki_romadhoni: retweet please..... \nmenu...                1
# 44    rt @teddygusnaidi: 2. anies dan agus adalah du...                1
# 46    rt @diki_romadhoni: retweet please..... \nmenu...                1
# 49    rt @teddygusnaidi: 5. tidak bisa dalam waktu 2...                1
# 51    rt @desvronitaaa: gitu yg mau jadi pemimpin? u...                0
# 54    rt @teddygusnaidi: yang dikiri dia pikir dia a...                0
# 55    rt @elyakin4: saya kaget lihat jempol bu silvy...                0
# 56    rt @erixputra: #debat2pilkadadki knp sylviana ...                0
# 59    rt @zul_hasan: sebelum debat kompak dukung agu...                1
# 61    rt @ariearie_14: debat kok saling menjatuhkan ...                0
# 63    rt @imadya: anies semakin terlihat aslinya. ma...                0
# 72    rt @annisapohon_: kata siapa mas agus enggak p...                0
# 73    rt @teddygusnaidi: 5. tidak bisa dalam waktu 2...                0
# 74    rt @teddygusnaidi: 15. ketidakberhasilan anies...                0
# ...                                                 ...              ...
# 1438  rt @nihaqus: anies: kalo jalan itu badan, tran...                0
# 1446  rt @teddygusnaidi: 5. tidak bisa dalam waktu 2...                1
# 1447  rt @aniesbaswedan: ibu, terima kasih atas doa ...                1
# 1448  rt @ponakannyaom: kembali saya ingatkan, siapa...                1
# 1449  rt @ronaldferdynand: hanya beliau yg berani me...                1
# 1457  rt @teddygusnaidi: yang dikiri dia pikir dia a...                1
# 1      nah gue pikir sentimen petahana oke di #debat...     True
# 9      ibu, terima kasih atas doa dan kumpulan pelaj...     True
# 10     sylviana kesyikan ngomong sendiri lupa bertan...     True
# 11     sylviana kesyikan ngomong sendiri lupa bertan...     True
# 12     sylviana kesyikan ngomong sendiri lupa bertan...     True
# 13     sylviana kesyikan ngomong sendiri lupa bertan...     True
# 21     sylviana kesyikan ngomong sendiri lupa bertan...     True
# 24     ini yg gue bilang, yg hebat di tim @agusyudho...     True
# 27     sy ga percaya mpok @sylviana_murni melakukan ...     True
# 28     sylviana kesyikan ngomong sendiri lupa bertan...     True
# 32     27. kalau gunakan fantasi agus maka agus bisa...     True
# 33     28. kalau gunakan fantasi anies, maka anies b...     True
# 34     para pemuja-pemuji @agusyudhoyono kalau msh j...     True
# 36     kata @aniesbaswedan ipm di ibu kota manapun d...     True
# 39     lah.. lu monolog sejam yg dihadiri orang2 lu ...     True
# 41     dari dulu sampe sekarang emang gak rubah sela...     True
# 42     retweet please..... \nmenurut anda, paslon ma...     True
# 44     2. anies dan agus adalah dua orang yg bermimp...     True
# 46     retweet please..... \nmenurut anda, paslon ma...     True
# 49     5. tidak bisa dalam waktu 2 tahun hrs membere...     True
# 51     gitu yg mau jadi pemimpin? udah salah harusny...     True
# 54     yang dikiri dia pikir dia ariel, yang ditenga...     True
# 55     saya kaget lihat jempol bu silvy kebawah saat...     True
# 56     #debat2pilkadadki knp sylviana mengacungkan j...     True
# 59     sebelum debat kompak dukung agus - sylvi. set...     True
# 61     debat kok saling menjatuhkan ki pie? dua dua ...     True
# 63     anies semakin terlihat aslinya. masyarakat su...     True
# 72     kata siapa mas agus enggak punya solusi utk m...     True
# 73     5. tidak bisa dalam waktu 2 tahun hrs membere...     True
# 74     15. ketidakberhasilan anies baswedan dalam me...     True
# ...                                                 ...      ...
# 1438   anies: kalo jalan itu badan, transportasi ada...     True
# 1446   5. tidak bisa dalam waktu 2 tahun hrs membere...     True
# 1447   ibu, terima kasih atas doa dan kumpulan pelaj...     True
# 1448   kembali saya ingatkan, siapa pun\n\nsekali la...     True
# 1449   hanya beliau yg berani menyatakan dirinya pel...     True
# 1457   yang dikiri dia pikir dia ariel, yang ditenga...     True
# 1458  ada yg jadi jd pemimpin 10 thn nggak jd apa, s...     True
# 1459  makin sering debat makin kelihatan karakter da...     True
# 1461   kebohongan telah di tebar @aniesbaswedan, seg...     True
# 1462   mpok @sylviana_murni salah sebut dg uu no 8 t...     True
# 1465   5. tidak bisa dalam waktu 2 tahun hrs membere...     True
# 1466   ibu, terima kasih atas doa dan kumpulan pelaj...     True
# 1468   16. anies baswedan hanya mengurus satu urusan...     True
# 1469   nah gue pikir sentimen petahana oke di #debat...     True
# 1470   28. kalau gunakan fantasi anies, maka anies b...     True
# 1474   ahok, agus, atau anis? atau pilih si anu? and...     True
# 1476   sylviana kesyikan ngomong sendiri lupa bertan...     True
# 1482   sylviana kesyikan ngomong sendiri lupa bertan...     True
# 1484   16. anies baswedan hanya mengurus satu urusan...     True
# 1485   15. ketidakberhasilan anies baswedan dalam me...     True
# 1488   sylviana kesyikan ngomong sendiri lupa bertan...     True
# 1489   15. ketidakberhasilan anies baswedan dalam me...     True
# 1490   15. ketidakberhasilan anies baswedan dalam me...     True
# 1491   16. anies baswedan hanya mengurus satu urusan...     True
# 1493   mengacungkan jari kebawah termasuk bagian dar...     True
# 1494   27. kalau gunakan fantasi agus maka agus bisa...     True
# 1496   retweet please..... \nmenurut anda, paslon ma...     True
# 1497   #debat2pilkadadki \nno 1 : paslon magang  (ba...     True
# 1499   sebelum debat kompak dukung agus - sylvi. set...     True
# 1505   guys, jangan lupa besok hari sidang ahok.\nse...     True
#
# [457 rows x 5 columns]

# %% [markdown]
# ## 3. ML Modelling

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df['no_link'], df['sentimen'], test_size = 0.3)

# %%
from imblearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score, f1_score, log_loss, matthews_corrcoef,precision_score,recall_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from imblearn.over_sampling import SMOTE

# %% [markdown]
# ### 3a. Count Vectoring and TF-IDF

# %%
word_transformer = CountVectorizer(ngram_range = (1,1)).fit(X_train)


# Print total number of vocab words
print(len(word_transformer.vocabulary_))
# Out:
# 12870

# %%
X_train_count_vectoring = word_transformer.transform(X_train)

# %%
tfidf_transformer = TfidfTransformer().fit(X_train_count_vectoring)

# %%
X_train_tfidf = tfidf_transformer.transform(X_train_count_vectoring)

# %%
test_transformer = CountVectorizer(ngram_range = (1,1)).fit(X_test)
X_test_count_vectoring = word_transformer.transform(X_test)
tfidf_transformer = TfidfTransformer().fit(X_test_count_vectoring)
X_test = tfidf_transformer.transform(X_test_count_vectoring)

# %% [markdown]
# ### 3b. Resampling

# %%
y_train.value_counts()
# Out:
#  0    3669
# -1    2005
#  1    1812
# Name: sentimen, dtype: int64

# %%
sm = SMOTE(sampling_strategy = 'minority')

# %%
oversampled_trainX, oversampled_trainY = sm.fit_sample(X_train_tfidf, y_train)

# %%
pd.Series(oversampled_trainY).value_counts()
# Out:
#  1    3669
#  0    3669
# -1    2005
# dtype: int64

# %%
oversampled_trainX, oversampled_trainY = sm.fit_sample(oversampled_trainX, oversampled_trainY)
pd.Series(oversampled_trainY).value_counts()
# Out:
# -1    3669
#  1    3669
#  0    3669
# dtype: int64

# %% [markdown]
# ### 3b. Calculate using NaiveBayes

# %%
ml_model = MultinomialNB().fit(oversampled_trainX, oversampled_trainY)
all_predictions = ml_model.predict(oversampled_trainX)
all_proba = ml_model.predict_proba(oversampled_trainX)

# %%
print (classification_report(oversampled_trainY, all_predictions))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.83      0.93      0.88      3669
#            0       0.93      0.76      0.84      3669
#            1       0.86      0.91      0.88      3669
#
#     accuracy                           0.87     11007
#    macro avg       0.87      0.87      0.87     11007
# weighted avg       0.87      0.87      0.87     11007

# %%
print (classification_report(y_test, ml_model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.47      0.64      0.54       866
#            0       0.73      0.51      0.60      1592
#            1       0.46      0.57      0.51       751
#
#     accuracy                           0.56      3209
#    macro avg       0.55      0.57      0.55      3209
# weighted avg       0.60      0.56      0.56      3209
